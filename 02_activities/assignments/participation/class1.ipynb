# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0,100,50) # (min, max, how many values)

fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
# adding labels and titles

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

ax.set_title('Total growth over time')
ax.set_ylabel('total Growth')
ax.set_xlabel('Years since start')
# Out:
# Text(0.5, 0, 'Years since start')

# %%
# adding font, style, color by modifing disctionary

font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

ax.set_title('Total growth over time',fontdict= font1)
ax.set_ylabel('total Growth', fontdict= font2)
ax.set_xlabel('Years since start', fontdict= font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
# modifying data plots
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y,
           marker = '*',
           color = 'indigo')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
           marker = '*',
           color = 'green',  # you can use #code instead of word
           linestyle = '--',
           linewidth = 2)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
           marker = '*',
           color = 'green',  # you can use #code instead of word
           linestyle = '--',
           linewidth = 2,
           markeredgecolor = '#FA9359', # orange
           markerfacecolor = '#000000') # black

# %%
# adding a grid line

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
           marker = '*',
           color = 'indigo',  # you can use #code instead of word
           linestyle = '--',
           linewidth = 2,
           markeredgecolor = '#FA9359', # orange
           markerfacecolor = '#000000') # black

#ax.grid(axis = 'x')  # only shows vertical x grids 
ax.grid(axis = 'y')  # only shows horizontal y grids 
#ax.grid()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
           marker = '*',
           color = 'cyan',  # you can use #code instead of word
           linestyle = ':',
           linewidth = 2,
           markeredgecolor = '#FA9359', # orange
           markerfacecolor = 'blue') # black

ax.grid(axis = 'x')  # only shows vertical x grids 
#ax.grid(axis = 'y')  # only shows horizontal y grids 
#ax.grid()

# %%
#plt.style.use('dark_background')


fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,
           marker = '*',
           color = 'cyan',  # you can use #code instead of word
           linestyle = ':',
           linewidth = 2,
           markeredgecolor = '#FA9359', # orange
           markerfacecolor = 'blue') # black

#ax.grid(axis = 'x')  # only shows vertical x grids 
ax.grid(axis = 'y')  # only shows horizontal y grids 
#ax.grid()

# %%
# sinusoidal lines with colors from default color cycle

fig, ax2 = plt.subplots(figsize=(5,3))

L = 2*np.pi
x = np.linspace(0, L)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax2.plot(x, np.sin(x + s), '-')
ax2.margins(0)

# %%
# import matplotlib.pyplot as plt
# import numpy as np

#plt.style.use('ggplot')

# Fixing random state for reproducibility
#np.random.seed(19680801)

fig, axs = plt.subplots(ncols=2, nrows=1)
ax1, ax2 = axs.flat

# scatter plot (Note: `plt.scatter` doesn't use default colors)
#x, y = np.random.normal(size=(2, 200))
#fig, ax = plt.subplots(figsize=(5,3))
ax1.plot(x,y,
           marker = '*',
           color = 'cyan',  # you can use #code instead of word
           linestyle = ':',
           linewidth = 2,
           markeredgecolor = '#FA9359', # orange
           markerfacecolor = 'blue') # black

#ax.grid(axis = 'x')  # only shows vertical x grids 
ax1.grid(axis = 'y')  # only shows horizontal y grids 
#ax.grid()
ax1.plot(x, y, 'o')

# sinusoidal lines with colors from default color cycle
plt.style.use('dark_background')

L = 2*np.pi
x = np.linspace(0, L)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax2.plot(x, np.sin(x + s), '-')
ax2.margins(0)
