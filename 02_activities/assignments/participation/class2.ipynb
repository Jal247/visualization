# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy

# %%
np.random.seed(613)  # in order to reproduce the same result everytime whoever can run this code
x = np.arange(50)  # generate a 50 numbers from 0 to 49
y1 = np.random.randint(0,100,50) # (min=0, max=100, how many values to generate=50)
y2 = np.random.randint(0,100,50)
#

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 
ax.plot(x,y1)
ax.plot(x,y2)

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 

ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc= "lower right")

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 

ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc= "lower right",
          frameon = True,
          fontsize = 12,
          ncol = 2,
          shadow = True)

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 

ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc= "upper left",        #  outside the box on
          bbox_to_anchor=(1,1))

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 

ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc= "upper right",        #  inside the box on
          bbox_to_anchor=(1,1))

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 

ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc= "upper right",        #  inside the box on
          bbox_to_anchor=(0,0))

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 

ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc= "upper right",        #  inside the box on
          bbox_to_anchor=(1,0))

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 

ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc= "upper right",        #  inside the box on
          bbox_to_anchor=(0,1))

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 

ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc= "lower right",        #  inside the box on
          bbox_to_anchor=(1,1),
            )
ax.text(10,95,"This value is important!") # at x=10 and y=95 point, where the anotation starts
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 

ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc= "lower right")        #  inside the box on
ax.text(10,95,"This value is important!",
        ha="center",
        color = 'red',
        size = 20) # at x=10 and y=95 point, where the anotation starts
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax = plt.subplots() #figsize we gave size of 5X3 inches 
ax.axis([0,10,0,10])
# Out:
# (0.0, 10.0, 0.0, 10.0)

# %%
fig, ax = plt.subplots() #figsize we gave size of 5X3 inches 
ax.axis([0,10,0,10])
ax.text(1,5,". Data:(1,5)", transform=ax.transData)
ax.text(0.5,0.1,". Axes: (0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2,0.2,". Figure: (0.2, 0.1)", transform=fig.transFigure)
# Out:
# Text(0.2, 0.2, '. Figure: (0.2, 0.1)')

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc = "lower right")

ax.annotate("This is important!", xy=(10,95),
            xytext= (20,94),
            arrowprops=dict(facecolor = 'hotpink', arrowstyle = "<->"))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc = "lower right")

ax.annotate("This is important!", xy=(10,95),
            xytext= (20,94),
            arrowprops=dict(facecolor = 'hotpink', arrowstyle = "wedge"))
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc = "lower right")

ax.yaxis.set_major_locator(plt.NullLocator(3))
#ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# ax.yaxis.set_major_locator(plt.MaxNLocator(3))
# ax.xaxis.set_major_locator(plt.MaxNLocator(3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       3 ax.scatter(x,y2,label="Person 2")
#       4 ax.legend(loc = "lower right")
# ----> 6 ax.yaxis.set_major_locator(plt.NullLocator(3))
#       7 #ax.xaxis.set_major_locator(plt.MaxNLocator(3))
#       8
#       9 # ax.yaxis.set_major_locator(plt.MaxNLocator(3))
#      10 # ax.xaxis.set_major_locator(plt.MaxNLocator(3))
#
# TypeError: NullLocator() takes no arguments

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc = "lower right")

#ax.yaxis.set_major_locator(plt.MaxNLocator(3))
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc = "lower right")

#ax.yaxis.set_major_locator(plt.MaxNLocator(3))
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
# axis labels rotation 
fig, ax = plt.subplots(figsize=(5,3)) #figsize we gave size of 5X3 inches 
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc = "lower right")
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
# axis roations
plt.xticks(rotation = 45,
           ha = "right",
           fontsize = 12,
           font = "serif")

#define the font 
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}
plt.xlabel('Shiney new X Axis!', fontsize = 18, fontdict = font1)
# Out:
# Text(0.5, 0, 'Shiney new X Axis!')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize = (5,3))

# %%
plt.style.use('dark_background')

fig, ax = plt.subplots(figsize = (5,3))
